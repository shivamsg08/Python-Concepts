# %% [markdown]
# Title : " Python - Data Visualization"
# @ Author : Shivam Goyal
#
# Date : 25 June, 2022
#
# Version 1
#
# https://matplotlib.org/stable/gallery/index.html

# %%
# load the data visualization packages
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Check or available style sheets
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
# use a specific style sheet for plots
plt.style.use('seaborn')

# %%
# Creating the line chart using the plot 
x = np.linspace(0, 10, 100)
y = 4 + 2 * (2 * x)

# plot
fig, ax = plt.subplots()
ax.plot(x,y)
plt.xlabel('X Axis')
plt.ylabel('Y axis')
plt.show()

# %%
import pandas as pd

a= pd.read_csv('D:/Part time Jobs/BusyQA/BusyQA/Shivam Analytics Teaching Material/6. Regression/Income.csv')
a.head()
# Out:
#    ID  Income  Age  Education  Gender
# 0   1     113   69         12       1
# 1   2      91   52         18       0
# 2   3     121   65         14       0
# 3   4      81   58         12       0
# 4   5      68   31         16       1

# %%
x = np.linspace(0, 10, 100)
y = 4 + np.sin(x)

# plot
fig, ax = plt.subplots()
plt.scatter(a.Age,a.Income,  c = 'b')
plt.xlabel('Age')
plt.ylabel('Income')
plt.show()

# %%
# Create two subplots and unpack the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharex='col' ,sharey=True) #all 'row'
ax1.plot(a.Age,a.Income)
ax1.set_title('Sharing Y axis')
ax2.scatter(a.Education,a.Income)

# %%
# Column Chart

# make data:
np.random.seed(3)
x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))

# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)
plt.show()

# %%
# plotting a histogram

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, (b,c,d) = plt.subplots(1,3)
b.hist(a.Income, bins=8, linewidth=0.5, edgecolor="white")
c.hist(a.Age, bins=8, linewidth=0.5, edgecolor="white")
d.hist(a.Education, bins=8, linewidth=0.5, edgecolor="white")
plt.show()

# %%
# make data:
np.random.seed(10)
D = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))

# plot
fig, ax = plt.subplots()
VP = ax.boxplot(D,showmeans=True, positions=[ 4, 5,6])
plt.show()

# %%
# plot
fig, ax = plt.subplots()
VP = ax.boxplot(a.Income,showmeans=True)
plt.show()

# %%
# Bar Chart with Labels

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
# ax.set_xticks(x,labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
# Stacked bar chart

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
# plt.rcdefaults()
fig, ax = plt.subplots()
# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
# ax.set_yticks(y_pos, labels=people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
# Plotting Multiple charts at once

data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %% [markdown]
# ### Using Seaborn library for Visualization

# %%
sns.set_theme(style="darkgrid")

# %%
data = sns.load_dataset('tips') # taxis/titanic

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
a.corr()
# Out:
#                  ID    Income       Age  Education    Gender
# ID         1.000000 -0.038846 -0.037770  -0.074147  0.005246
# Income    -0.038846  1.000000  0.761486   0.256634 -0.045060
# Age       -0.037770  0.761486  1.000000   0.026254 -0.027242
# Education -0.074147  0.256634  0.026254   1.000000 -0.004843
# Gender     0.005246 -0.045060 -0.027242  -0.004843  1.000000

# %%
# Creating a Heatmap for corrleation plot
sns.heatmap(a.corr())
# Out:
# <AxesSubplot:>

# %%
sns.relplot(x="Age", y="Income",kind="line" ,data=a) #hue="smoker", hue="size",  style="smoker", for third dimension

# %%
# sns.regplot(x=data['total_bill'],y = data['tip'])
sns.regplot(x=a['Age'],y = a['Income'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Income'>

# %%
import pandas as pd

df = pd.DataFrame(dict(time=np.arange(10),
                       value=np.random.randn(10).cumsum()))
g = sns.relplot(x="time", y="value",markers=True, kind="line", data=df)
g.figure.autofmt_xdate()

# %%
sns.pairplot(a)

# %%
sns.distplot(a['Income'])
# Out:
# C:\Users\Shivam Goyal\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Income', ylabel='Density'>

# %%
sns.jointplot(x='tip',y='total_bill',data=data,kind='hex')

# %%
sns.jointplot(x=data['total_bill'],y=data['size'])

# %%
sns.countplot(data['smoker'],hue=data['sex'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.violinplot(x = data['total_bill'],y = data['smoker'],hue=data['sex'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='smoker'>

# %%
sns.boxplot(a['Income'])
# Out:
# C:\Users\Shivam Goyal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Income'>
